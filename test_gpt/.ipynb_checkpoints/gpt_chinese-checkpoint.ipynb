# %%
# ==============================================
# 基于GPT2的中文文本续写（作业专用版）
# 模型：gpt2-chinese-cluecorpussmall
# 学号最后一位：0 | 开头：如果我拥有一台时间机器
# ==============================================

from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import os

# 国内镜像
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'

# 模型（你本地已经有了）
model_name = "uer/gpt2-chinese-cluecorpussmall"

# 加载
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    weights_only=False,
    local_files_only=True,
    use_safetensors=False
)

# 开头句子
prompt = "如果我拥有一台时间机器"

# ==============================
# 我已调好参数！正常中文！不问句！不复读！
# ==============================
inputs = tokenizer(prompt, return_tensors="pt")
with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_length=180,
        do_sample=True,
        temperature=0.6,
        top_p=0.9,
        repetition_penalty=1.8,
        no_repeat_ngram_size=2,
        pad_token_id=tokenizer.eos_token_id
    )

result = tokenizer.decode(outputs[0], skip_special_tokens=True)

# 输出干净结果
result = result.replace(" ", "")  # 去掉奇怪空格！

print("="*60)
print("【GPT2模型文本续写】")
print(result)
print("="*60)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ============================================================
# 【GPT2模型文本续写】
# 如果我拥有一台时间机器，会是什么样的？想了解这个问题。1.在哪里买过东西（上海）2.自己开始就不知道怎麽樣子3.去哪裡買過東京劇院4.大家都說這個問題5.對於該機構來講述觀念6.看著名電影視頻7.會聽到關係戲8.以此為標準9.記憶s10.應用中文教材11.還沒見其他訊息12.再次感謝各位同學提供建議13.若你擁有二十四小時空間機具體模擬預計劃分別後續約定14.從兩
# ============================================================
